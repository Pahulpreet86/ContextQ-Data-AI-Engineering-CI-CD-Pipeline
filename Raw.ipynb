# %%
import pandas as pd

# %%
df=pd.read_csv("/home/pahul/Documents/entity-resolution/dataset/top_technology_companies.csv")

# %%
df.columns
# Out:
# Index(['Ranking', 'Company', 'Market Cap', 'Stock', 'Country', 'Sector',
#        'Industry'],
#       dtype='object')

# %%
df.head()
# Out:
#    Ranking                                            Company Market Cap  \
# 0        1                                         Apple Inc.   $2.866 T
# 1        2                              Microsoft Corporation   $2.755 T
# 2        3                                 Nvidia Corporation   $1.186 T
# 3        4                                      Broadcom Inc.  $495.95 B
# 4        5  Taiwan Semiconductor Manufacturing Company Lim...  $487.64 B
#
#   Stock        Country      Sector                 Industry
# 0  AAPL  United States  Technology     Consumer Electronics
# 1  MSFT  United States  Technology  Software—Infrastructure
# 2  NVDA  United States  Technology           Semiconductors
# 3  AVGO  United States  Technology           Semiconductors
# 4  2330         Taiwan  Technology           Semiconductors

# %%
df.columns=['ranking', 'company', 'market_cap', 'stock', 'country', 'sector',
       'industry']

# %%
df.to_csv("/home/pahul/Documents/entity-resolution/dataset/technology_companies_raw.csv")

# %%
df1=pd.read_csv("/home/pahul/Documents/entity-resolution/dataset/tech_companies_raw.csv")

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'name', 'domain', 'year founded', 'industry',
#        'size range', 'locality', 'country', 'linkedin url',
#        'current employee estimate', 'total employee estimate'],
#       dtype='object')

# %%
df1=df1[[ 'name', 'domain', 'year founded', 'industry',
       'size range', 'locality', 'country', 'linkedin url',
       'current employee estimate', 'total employee estimate']]

# %%
df1.columns=['name', 'domain', 'year_founded', 'industry', 'size_range', 'locality',
       'country', 'linkedin_url', 'current_employee_estimate',
       'total_employee_estimate']

# %%
df1.to_csv("/home/pahul/Documents/entity-resolution/dataset/companies_raw.csv",index=False)

# %%
len(df1)
# Out:
# 7173426

# %%
df1.to_parquet("/home/pahul/Documents/entity-resolution/dataset/companies_raw.parquet", engine="pyarrow")

# %%
df.to_parquet("/home/pahul/Documents/entity-resolution/dataset/technology_companies_raw.parquet", engine="pyarrow")

# %%
df=pd.read_csv("/home/pahul/Documents/entity-resolution/dataset/raw/companies_raw.csv")
df1=pd.read_csv("/home/pahul/Documents/entity-resolution/dataset/raw/technology_companies_raw.csv")

# %%
df['country'].unique()
# Out:
# array(['united states', 'india', 'ireland', 'united kingdom', 'germany',
#        'finland', 'france', 'sweden', nan, 'netherlands', 'switzerland',
#        'china', 'canada', 'spain', 'brazil', 'saudi arabia', 'australia',
#        'turkey', 'czechia', 'united arab emirates', 'south korea',
#        'singapore', 'south africa', 'mexico', 'taiwan', 'japan',
#        'belgium', 'italy', 'colombia', 'algeria', 'norway', 'qatar',
#        'venezuela', 'indonesia', 'malaysia', 'denmark', 'luxembourg',
#        'hong kong', 'philippines', 'austria', 'chile', 'new zealand',
#        'kuwait', 'argentina', 'peru', 'greece', 'liechtenstein', 'oman',
#        'russia', 'pakistan', 'lebanon', 'uruguay', 'bermuda', 'iran',
#        'nigeria', 'egypt', 'poland', 'thailand', 'jamaica', 'morocco',
#        'romania', 'bangladesh', 'israel', 'jordan', 'kenya', 'sri lanka',
#        'puerto rico', 'kazakhstan', 'estonia', 'costa rica', 'portugal',
# ...

# %%
print(df1['country'].apply(lambda x: x.lower()).unique())
# Out:
# ['united states' 'taiwan' 'south korea' 'netherlands' 'ireland' 'germany'
#  'japan' 'hong kong' 'canada' 'india' 'france' 'australia' 'bermuda'
#  'china' 'switzerland' 'sweden' 'spain' 'finland' 'kazakhstan' 'israel'
#  'united kingdom' 'new zealand' 'italy' 'singapore' 'luxembourg' 'czechia'
#  'cayman islands' 'denmark' 'brazil' 'belgium' 'norway'
#  'united arab emirates' 'turkey' 'thailand' 'mauritius' 'poland' 'austria'
#  'portugal']

# %%
clist=['united states', 'taiwan', 'south korea', 'netherlands', 'ireland',
       'germany', 'japan', 'hong kong', 'canada', 'india', 'france',
       'australia', 'bermuda', 'china', 'switzerland', 'sweden', 'spain',
       'finland', 'kazakhstan', 'israel', 'united kingdom', 'new zealand',
       'italy', 'singapore', 'luxembourg', 'czechia', 'cayman islands',
       'denmark', 'brazil', 'belgium', 'norway', 'united arab emirates',
       'turkey', 'thailand', 'mauritius', 'poland', 'austria', 'portugal']

# %%
df['country'].apply(lambda x: str(x).lower()).unique()
# Out:
# array(['united states', 'india', 'ireland', 'united kingdom', 'germany',
#        'finland', 'france', 'sweden', 'nan', 'netherlands', 'switzerland',
#        'china', 'canada', 'spain', 'brazil', 'saudi arabia', 'australia',
#        'turkey', 'czechia', 'united arab emirates', 'south korea',
#        'singapore', 'south africa', 'mexico', 'taiwan', 'japan',
#        'belgium', 'italy', 'colombia', 'algeria', 'norway', 'qatar',
#        'venezuela', 'indonesia', 'malaysia', 'denmark', 'luxembourg',
#        'hong kong', 'philippines', 'austria', 'chile', 'new zealand',
#        'kuwait', 'argentina', 'peru', 'greece', 'liechtenstein', 'oman',
#        'russia', 'pakistan', 'lebanon', 'uruguay', 'bermuda', 'iran',
#        'nigeria', 'egypt', 'poland', 'thailand', 'jamaica', 'morocco',
#        'romania', 'bangladesh', 'israel', 'jordan', 'kenya', 'sri lanka',
#        'puerto rico', 'kazakhstan', 'estonia', 'costa rica', 'portugal',
# ...

# %%
elist=['united states', 'india', 'ireland', 'united kingdom', 'germany',
       'finland', 'france', 'sweden', 'nan', 'netherlands', 'switzerland',
       'china', 'canada', 'spain', 'brazil', 'saudi arabia', 'australia',
       'turkey', 'czechia', 'united arab emirates', 'south korea',
       'singapore', 'south africa', 'mexico', 'taiwan', 'japan',
       'belgium', 'italy', 'colombia', 'algeria', 'norway', 'qatar',
       'venezuela', 'indonesia', 'malaysia', 'denmark', 'luxembourg',
       'hong kong', 'philippines', 'austria', 'chile', 'new zealand',
       'kuwait', 'argentina', 'peru', 'greece', 'liechtenstein', 'oman',
       'russia', 'pakistan', 'lebanon', 'uruguay', 'bermuda', 'iran',
       'nigeria', 'egypt', 'poland', 'thailand', 'jamaica', 'morocco',
       'romania', 'bangladesh', 'israel', 'jordan', 'kenya', 'sri lanka',
       'puerto rico', 'kazakhstan', 'estonia', 'costa rica', 'portugal',
       'ukraine', 'ethiopia', 'panama', 'vietnam', 'cyprus', 'tunisia',
       'hungary', 'latvia', 'uganda', 'serbia', 'croatia',
       'cayman islands', 'fiji', 'slovenia', 'iceland', 'palestine',
       'zimbabwe', 'bahrain', 'ghana', 'papua new guinea',
       'trinidad and tobago', 'dominican republic', 'jersey', 'angola',
       'slovakia', 'bulgaria', 'guatemala', 'saint lucia', 'senegal',
       'georgia', 'ecuador', 'lithuania', 'madagascar', 'mauritius',
       'honduras', 'macau', 'syria', 'cameroon', 'nepal', 'iraq', 'malta',
       'zambia', 'tanzania', 'monaco', 'azerbaijan', 'isle of man',
       'brunei', 'namibia', 'grenada', 'botswana', 'bhutan',
       'el salvador', 'mozambique', 'french polynesia',
       'equatorial guinea', 'gibraltar', 'cuba', 'belarus', 'armenia',
       'afghanistan', 'micronesia', 'dominica', 'sudan', 'côte d’ivoire',
       'myanmar', 'bahamas', 'mongolia', 'albania', 'macedonia',
       'bolivia', 'curaçao', 'suriname', 'paraguay', 'guernsey',
       'martinique', 'moldova', 'bosnia and herzegovina', 'cambodia',
       'new caledonia', 'guam', 'réunion', 'malawi', 'nicaragua',
       'rwanda', 'greenland', 'andorra', 'libya', 'benin', 'burkina faso',
       'maldives', 'democratic republic of the congo', 'uzbekistan',
       'belize', 'somalia', 'swaziland', 'british virgin islands',
       'guadeloupe', 'lesotho', 'gambia', 'guinea', 'montenegro',
       'sierra leone', 'french guiana', 'guyana', 'south sudan',
       'netherlands antilles', 'niger', 'american samoa', 'åland islands',
       'kyrgyzstan', 'mali', 'laos', 'yemen', 'liberia', 'tajikistan',
       'aruba', 'saint vincent and the grenadines', 'marshall islands',
       'san marino', 'togo', 'djibouti', 'montserrat', 'faroe islands',
       'saint kitts and nevis', 'anguilla', 'kosovo', 'kiribati',
       'cape verde', 'gabon', 'vanuatu', 'mauritania', 'turkmenistan',
       'cook islands', 'seychelles', 'barbados', 'mayotte',
       'guinea-bissau', 'tuvalu', 'svalbard and jan mayen', 'eritrea',
       'haiti', 'turks and caicos islands', 'burundi', 'solomon islands',
       'palau', 'northern mariana islands', 'samoa', 'tonga',
       'central african republic', 'são tomé and príncipe',
       'western sahara', 'chad', 'caribbean netherlands', 'saint helena',
       'sint maarten', 'timor-leste', 'north korea', 'comoros',
       'antigua and barbuda', 'republic of the congo', 'niue',
       'saint martin', 'u.s. virgin islands', 'norfolk island',
       'saint pierre and miquelon', 'saint barthélemy']

# %%
len([x for x in clist if x not in elist])
# Out:
# 0

# %%
len(df['industry'].unique())
# Out:
# 149

# %%
df1['industry'].apply(lambda x: str(x).lower()).unique()
# Out:
# array(['consumer electronics', 'software—infrastructure',
#        'semiconductors', 'semiconductor equipment & materials',
#        'software—application', 'information technology services',
#        'communication equipment', 'scientific & technical instruments',
#        'computer hardware', 'electronic components', 'solar',
#        'electronics & computer distribution'], dtype=object)

# %%
mapping = {
    'information technology and services': 'information technology services',
    'military': 'N/A',
    'accounting': 'N/A',
    'retail': 'electronics & computer distribution',
    'computer software': 'software—application',
    'telecommunications': 'communication equipment',
    'defense & space': 'N/A',
    'fiNonecial services': 'N/A',
    'management consulting': 'N/A',
    'banking': 'N/A',
    'internet': 'software—infrastructure',
    'consumer electronics': 'consumer electronics',
    'electrical/electronic manufacturing': 'electronic components',
    'public policy': 'N/A',
    'government administration': 'N/A',
    'restaurants': 'N/A',
    'hospital & health care': 'N/A',
    'aviation & aerospace': 'N/A',
    'automotive': 'electronic components',
    'semiconductors': 'semiconductors',
    'computer networking': 'communication equipment',
    'food & beverages': 'N/A',
    'oil & energy': 'N/A',
    'transportation/trucking/railroad': 'N/A',
    'pharmaceuticals': 'N/A',
    'consumer goods': 'N/A',
    'design': 'N/A',
    'education management': 'N/A',
    'insurance': 'N/A',
    'photography': 'consumer electronics',
    'logistics and supply chain': 'N/A',
    'publishing': 'N/A',
    'real estate': 'N/A',
    'translation and localization': 'N/A',
    'facilities services': 'N/A',
    'investment banking': 'N/A',
    'cosmetics': 'N/A',
    'human resources': 'N/A',
    'medical devices': 'scientific & technical instruments',
    'biotechnology': 'N/A',
    'mechanical or industrial engineering': 'N/A',
    'broadcast media': 'N/A',
    'hospitality': 'N/A',
    'sporting goods': 'N/A',
    'chemicals': 'semiconductor equipment & materials',
    'airlines/aviation': 'N/A',
    'commercial real estate': 'N/A',
    'construction': 'N/A',
    'security and investigations': 'N/A',
    'supermarkets': 'N/A',
    'health, wellness and fitness': 'N/A',
    'food production': 'N/A',
    'civil engineering': 'N/A',
    'medical practice': 'N/A',
    'media production': 'N/A',
    'machinery': 'semiconductor equipment & materials',
    'utilities': 'N/A',
    'textiles': 'N/A',
    'research': 'scientific & technical instruments',
    'package/freight delivery': 'N/A',
    'mining & metals': 'semiconductor equipment & materials',
    'mental health care': 'N/A',
    'outsourcing/offshoring': 'information technology services',
    'professional training & coaching': 'N/A',
    'entertainment': 'N/A',
    'information services': 'software—infrastructure',
    'international affairs': 'N/A',
    'wireless': 'communication equipment',
    'writing and editing': 'N/A',
    'building materials': 'N/A',
    'higher education': 'N/A',
    'law practice': 'N/A',
    'computer hardware': 'computer hardware',
    'tobacco': 'N/A',
    'railroad manufacture': 'N/A',
    'international trade and development': 'N/A',
    'public relations and communications': 'N/A',
    'non-profit organization management': 'N/A',
    'printing': 'N/A',
    'staffing and recruiting': 'N/A',
    'environmental services': 'N/A',
    'capital markets': 'N/A',
    'farming': 'N/A',
    'business supplies and equipment': 'N/A',
    'primary/secondary education': 'N/A',
    'legislative office': 'N/A',
    'industrial automation': 'electronic components',
    'wine and spirits': 'N/A',
    'paper & forest products': 'N/A',
    'leisure, travel & tourism': 'N/A',
    'arts and crafts': 'N/A',
    'packaging and containers': 'N/A',
    'marketing and advertising': 'N/A',
    'civic & social organization': 'N/A',
    'apparel & fashion': 'N/A',
    'individual & family services': 'N/A',
    'music': 'N/A',
    'motion pictures and film': 'N/A',
    'graphic design': 'N/A',
    'luxury goods & jewelry': 'N/A',
    'renewables & environment': 'solar',
    'legal services': 'N/A',
    'consumer services': 'N/A',
    'law enforcement': 'N/A',
    'philanthropy': 'N/A',
    'wholesale': 'electronics & computer distribution',
    'glass, ceramics & concrete': 'N/A',
    'judiciary': 'N/A',
    'maritime': 'N/A',
    'market research': 'N/A',
    'government relations': 'N/A',
    'dairy': 'N/A',
    'public safety': 'N/A',
    'recreational facilities and services': 'N/A',
    'gambling & casinos': 'N/A',
    'computer games': 'software—application',
    'religious institutions': 'N/A',
    'warehousing': 'N/A',
    'newspapers': 'N/A',
    'fishery': 'N/A',
    'political organization': 'N/A',
    'investment management': 'N/A',
    'animation': 'software—application',
    'computer & network security': 'software—infrastructure',
    'architecture & planning': 'N/A',
    'e-learning': 'software—application',
    'import and export': 'N/A',
    'events services': 'N/A',
    'online media': 'software—application',
    'furniture': 'N/A',
    'plastics': 'electronic components',
    'sports': 'N/A',
    'veterinary': 'N/A',
    'executive office': 'N/A',
    'program development': 'N/A',
    'fine art': 'N/A',
    'fund-raising': 'N/A',
    'alternative dispute resolution': 'N/A',
    'museums and institutions': 'N/A',
    'alternative medicine': 'N/A',
    'think tanks': 'N/A',
    'shipbuilding': 'N/A',
    'nonprofit organization management': 'N/A',
    'libraries': 'N/A',
    'performing arts': 'N/A',
    'venture capital & private equity': 'N/A',
    'Noneotechnology': 'semiconductor equipment & materials',
    'ranching': 'N/A',
}

# %%
print(mapping)
# Out:
# {'information technology and services': 'information technology services', 'military': 'N/A', 'accounting': 'N/A', 'retail': 'electronics & computer distribution', 'computer software': 'software—application', 'telecommunications': 'communication equipment', 'defense & space': 'N/A', 'fiNonecial services': 'N/A', 'management consulting': 'N/A', 'banking': 'N/A', 'internet': 'software—infrastructure', 'consumer electronics': 'consumer electronics', 'electrical/electronic manufacturing': 'electronic components', 'public policy': 'N/A', 'government administration': 'N/A', 'restaurants': 'N/A', 'hospital & health care': 'N/A', 'aviation & aerospace': 'N/A', 'automotive': 'electronic components', 'semiconductors': 'semiconductors', 'computer networking': 'communication equipment', 'food & beverages': 'N/A', 'oil & energy': 'N/A', 'transportation/trucking/railroad': 'N/A', 'pharmaceuticals': 'N/A', 'consumer goods': 'N/A', 'design': 'N/A', 'education management': 'N/A', 'insurance': 'N/A', 
# ...

# %%
industry_mapping={'information technology and services': 'information technology services', 'military': 'N/A', 'accounting': 'N/A', 'retail': 'electronics & computer distribution', 'computer software': 'software—application', 'telecommunications': 'communication equipment', 'defense & space': 'N/A', 'fiNonecial services': 'N/A', 'management consulting': 'N/A', 'banking': 'N/A', 'internet': 'software—infrastructure', 'consumer electronics': 'consumer electronics', 'electrical/electronic manufacturing': 'electronic components', 'public policy': 'N/A', 'government administration': 'N/A', 'restaurants': 'N/A', 'hospital & health care': 'N/A', 'aviation & aerospace': 'N/A', 'automotive': 'electronic components', 'semiconductors': 'semiconductors', 'computer networking': 'communication equipment', 'food & beverages': 'N/A', 'oil & energy': 'N/A', 'transportation/trucking/railroad': 'N/A', 'pharmaceuticals': 'N/A', 'consumer goods': 'N/A', 'design': 'N/A', 'education management': 'N/A', 'insurance': 'N/A', 'photography': 'consumer electronics', 'logistics and supply chain': 'N/A', 'publishing': 'N/A', 'real estate': 'N/A', 'translation and localization': 'N/A', 'facilities services': 'N/A', 'investment banking': 'N/A', 'cosmetics': 'N/A', 'human resources': 'N/A', 'medical devices': 'scientific & technical instruments', 'biotechnology': 'N/A', 'mechanical or industrial engineering': 'N/A', 'broadcast media': 'N/A', 'hospitality': 'N/A', 'sporting goods': 'N/A', 'chemicals': 'semiconductor equipment & materials', 'airlines/aviation': 'N/A', 'commercial real estate': 'N/A', 'construction': 'N/A', 'security and investigations': 'N/A', 'supermarkets': 'N/A', 'health, wellness and fitness': 'N/A', 'food production': 'N/A', 'civil engineering': 'N/A', 'medical practice': 'N/A', 'media production': 'N/A', 'machinery': 'semiconductor equipment & materials', 'utilities': 'N/A', 'textiles': 'N/A', 'research': 'scientific & technical instruments', 'package/freight delivery': 'N/A', 'mining & metals': 'semiconductor equipment & materials', 'mental health care': 'N/A', 'outsourcing/offshoring': 'information technology services', 'professional training & coaching': 'N/A', 'entertainment': 'N/A', 'information services': 'software—infrastructure', 'international affairs': 'N/A', 'wireless': 'communication equipment', 'writing and editing': 'N/A', 'building materials': 'N/A', 'higher education': 'N/A', 'law practice': 'N/A', 'computer hardware': 'computer hardware', 'tobacco': 'N/A', 'railroad manufacture': 'N/A', 'international trade and development': 'N/A', 'public relations and communications': 'N/A', 'non-profit organization management': 'N/A', 'printing': 'N/A', 'staffing and recruiting': 'N/A', 'environmental services': 'N/A', 'capital markets': 'N/A', 'farming': 'N/A', 'business supplies and equipment': 'N/A', 'primary/secondary education': 'N/A', 'legislative office': 'N/A', 'industrial automation': 'electronic components', 'wine and spirits': 'N/A', 'paper & forest products': 'N/A', 'leisure, travel & tourism': 'N/A', 'arts and crafts': 'N/A', 'packaging and containers': 'N/A', 'marketing and advertising': 'N/A', 'civic & social organization': 'N/A', 'apparel & fashion': 'N/A', 'individual & family services': 'N/A', 'music': 'N/A', 'motion pictures and film': 'N/A', 'graphic design': 'N/A', 'luxury goods & jewelry': 'N/A', 'renewables & environment': 'solar', 'legal services': 'N/A', 'consumer services': 'N/A', 'law enforcement': 'N/A', 'philanthropy': 'N/A', 'wholesale': 'electronics & computer distribution', 'glass, ceramics & concrete': 'N/A', 'judiciary': 'N/A', 'maritime': 'N/A', 'market research': 'N/A', 'government relations': 'N/A', 'dairy': 'N/A', 'public safety': 'N/A', 'recreational facilities and services': 'N/A', 'gambling & casinos': 'N/A', 'computer games': 'software—application', 'religious institutions': 'N/A', 'warehousing': 'N/A', 'newspapers': 'N/A', 'fishery': 'N/A', 'political organization': 'N/A', 'investment management': 'N/A', 'animation': 'software—application', 'computer & network security': 'software—infrastructure', 'architecture & planning': 'N/A', 'e-learning': 'software—application', 'import and export': 'N/A', 'events services': 'N/A', 'online media': 'software—application', 'furniture': 'N/A', 'plastics': 'electronic components', 'sports': 'N/A', 'veterinary': 'N/A', 'executive office': 'N/A', 'program development': 'N/A', 'fine art': 'N/A', 'fund-raising': 'N/A', 'alternative dispute resolution': 'N/A', 'museums and institutions': 'N/A', 'alternative medicine': 'N/A', 'think tanks': 'N/A', 'shipbuilding': 'N/A', 'nonprofit organization management': 'N/A', 'libraries': 'N/A', 'performing arts': 'N/A', 'venture capital & private equity': 'N/A', 'Noneotechnology': 'semiconductor equipment & materials', 'ranching': 'N/A'}

# %%
print({x:y for x,y in industry_mapping.items() if y!='N/A'})
# Out:
# {'information technology and services': 'information technology services', 'retail': 'electronics & computer distribution', 'computer software': 'software—application', 'telecommunications': 'communication equipment', 'internet': 'software—infrastructure', 'consumer electronics': 'consumer electronics', 'electrical/electronic manufacturing': 'electronic components', 'automotive': 'electronic components', 'semiconductors': 'semiconductors', 'computer networking': 'communication equipment', 'photography': 'consumer electronics', 'medical devices': 'scientific & technical instruments', 'chemicals': 'semiconductor equipment & materials', 'machinery': 'semiconductor equipment & materials', 'research': 'scientific & technical instruments', 'mining & metals': 'semiconductor equipment & materials', 'outsourcing/offshoring': 'information technology services', 'information services': 'software—infrastructure', 'wireless': 'communication equipment', 'computer hardware': 'computer hardware', 'in
# ...

# %%
import pandas as pd

df = pd.read_parquet("/home/pahul/Documents/entity-resolution/dataset/bronze/companies_raw.parquet")

print(df.head())
# Out:
#                         name         domain  year_founded  \
# 0                        ibm        ibm.com        1911.0
# 1  tata consultancy services        tcs.com        1968.0
# 2                  accenture  accenture.com        1989.0
# 3                    us army     goarmy.com        1800.0
# 4                         ey         ey.com        1989.0
#
#                               industry size_range  \
# 0  information technology and services     10001+
# 1  information technology and services     10001+
# 2  information technology and services     10001+
# 3                             military     10001+
# 4                           accounting     10001+
#
#                                  locality         country  \
# 0       new york, new york, united states   united states
# 1              bombay, maharashtra, india           india
# 2                 dublin, dublin, ireland         ireland
# 3     alexandria, virginia, united states   united states
# ...

# %%
sample_df = df.sample(n=1000, random_state=42)

# Save as parquet
sample_df.to_parquet(
    "/home/pahul/Documents/entity-resolution/dataset/bronze/companies_sample_1000.parquet",
    index=False
)
